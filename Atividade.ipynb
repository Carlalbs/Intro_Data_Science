# %% [markdown]
# <a href="https://colab.research.google.com/github/Carlalbs/Intro_Data_Science/blob/main/Atividade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Introdução

# %% [markdown]
# #### 1. Faça um código em que seja emitida a mensagem "Bem vindo!":

# %%
print("Bem-vindo!")
# Out:
# Bem-vindo!

# %% [markdown]
# #### 2. Faça um código em que seja pedido ao usuário que ele informe sua idade e então mostre a mensagem: "A idade informada foi XX anos."

# %%
idade = input("informe sua idade: ")
print("A idade informada foi", idade, "anos")
# Out:
# informe sua idade: 28
# A idade informada foi 28 anos

# %% [markdown]
# #### 3. Crie um código em que o usuário tenha que informar dois tipos de rendimentos que possui "Salário" e "Aluguel". Em seguida crie um código que informe na tela a soma desses dois rendimentos (Rendimentos Totais):

# %%
salario = float(input("informe o valor do salario: "))
aluguel = float(input("informe o valor do aluguel: "))
rendimentos_totais = salario + aluguel
print("Rendiemntos Totais:", rendimentos_totais)
# Out:
# informe o valor do salario: 1621
# informe o valor do aluguel: 450
# Rendiemntos Totais: 2071.0

# %% [markdown]
# #### 4. Crie um código que solicite ao usuário as informações das quatro notas obtidas numa disciplina. Em seguida crie um código onde seja apresentado ao usuário a média final nessa disciplina.

# %%
nota1 = float(input("informe a primeira nota: "))
nota2 = float(input("informe a segunda nota: "))
nota3 = float(input("informe a terceira nota: "))
nota4 = float(input("informe a quarta nota: "))
media = (nota1 + nota2 + nota3 + nota4) / 4
print("A média final da disciplina é: ", media)
# Out:
# informe a primeira nota: 9.5
# informe a segunda nota: 8.0
# informe a terceira nota: 10.0
# informe a quarta nota: 7.5
# A média final da disciplina é:  8.75

# %% [markdown]
# #### 5. Faça um código que calcule e mostre a área de um ambiente qualquer (em m²). Para isso, o seu código precisa solicitar ao usuário que sejam informados a largura e o comprimento do ambiente.

# %%
largura = float(input("informe a largura do ambiente (em metros): "))
comprimento = float(input("informe o comprimento do ambiente (em metros): "))
area = largura * comprimento
print("A área do ambiente é:", area, "m" )
# Out:
# informe a largura do ambiente (em metros): 4
# informe o comprimento do ambiente (em metros): 5
# A área do ambiente é: 20.0 m

# %% [markdown]
# #### 6. Crie um código que pergunte ao usuário quantos anos ele tem e quantos anos o filho dele tem; em seguida crie um código que informe quantos dias de vida cada um teve e quantos dias de vida o pai/mãe têve a mais que o filho (considere o ano com 365 dias).

# %%
idade_mae = int(input("informe a idade do pai/mae: "))
idade_filha = int(input("informe a idade do filho: "))
dias_mae = idade_mae * 365
dias_filha = idade_filha * 365
diferenca = dias_mae - dias_filha
print("O pai/mãe viveu", dias_mae, "dias")
print("A filha viveu", dias_filha, "dias")
print("O pai/mãe viveu", diferenca, "dias a mais que o filho")
# Out:
# informe a idade do pai/mae: 54
# informe a idade do filho: 28
# O pai/mãe viveu 19710 dias
# A filha viveu 10220 dias
# O pai/mãe viveu 9490 dias a mais que o filho

# %% [markdown]
# #### 7. Vamos criar um conversor de temperatura. Faça um Programa que peça a temperatura em graus Fahrenheit, transforme e mostre a temperatura em graus Celsius.
# $$C = \frac{5}{9} * (F-32)$$

# %%
fahrenheit = float(input("informe a temperatura em graus Fahrenheit: "))
celsius = (5/9) * (fahrenheit - 32)
print("A temperatura em graus Celsius é:", celsius)
# Out:
# informe a temperatura em graus Fahrenheit: 86
# A temperatura em graus Celsius é: 30.0

# %% [markdown]
# #### 8. Tendo como dados de entrada a altura (h) de uma pessoa, construa um código que calcule seu peso ideal, usando a seguinte fórmula:
# $$P = 72,7h - 58$$

# %%
altura = float(input("informe sua altura (em metros): "))
peso_ideal = (72.7 * altura) - 58
print("Seu peso ideal é:", peso_ideal, "kg")
# Out:
# informe sua altura (em metros): 1.60
# Seu peso ideal é: 58.32000000000001 kg

# %% [markdown]
# #### 9. Faça um código que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Ao final o código deve apresentar o valor do Salário Bruto, que corresponde ao produto (multiplicação) entre o valor ganho por hora e o número de horas trabalhadas no mês.

# %%
valor_hora = float(input("quando você ganha por hora? "))
horas_trabalhadas = float(input("quantas horas você trabalhou no mês? "))
salario_bruto = valor_hora * horas_trabalhadas
print("O salário bruto é: R$", salario_bruto)
# Out:
# quando você ganha por hora? 9.21
# quantas horas você trabalhou no mês? 176
# O salário bruto é: R$ 1620.96

# %% [markdown]
# ##### 9.1 - Tendo por base o valor do Salário Bruto, crie um código que calcule os seguintes descontos: Imposto de Renda (11%), Previdência Social (8%), Sindicato (1%). Depois de calcular cada desconto, crie um código que calcule o valor dos Descontos Totais, que corresponde ao somatório de todos os descontos.

# %%
salario_bruto = float(input("informe o valor do salario bruto: R$ "))
imposto_renda = salario_bruto * 0.11
previdencia = salario_bruto * 0.08
sindicato = salario_bruto * 0.01
descontos_totais = imposto_renda + previdencia + sindicato
print("Imposto de Renda: R$", imposto_renda)
print("Previdencia: R$", previdencia)
print("Sindicato: R$", sindicato)
print("Descontos Totais: R$", descontos_totais)
# Out:
# informe o valor do salario bruto: R$ 1620.96
# Imposto de Renda: R$ 178.3056
# Previdencia: R$ 129.67680000000001
# Sindicato: R$ 16.209600000000002
# Descontos Totais: R$ 324.192

# %% [markdown]
# ##### 9.2 - Crie um código que calcule o Salário Líquido (Salário Bruto - Descontos Totais)

# %%
salario_bruto = float(input("informe o salario bruto: R$ "))
descontos_totais = float(input("informe o valor dos descontos totais: R$ "))
salario_liquido = salario_bruto - descontos_totais
print("O salario líquido é: R$", salario_liquido)
# Out:
# informe o salario bruto: R$ 1620.96
# informe o valor dos descontos totais: R$ 324.192
# O salario líquido é: R$ 1296.768

# %% [markdown]
# #### 10. Faça um código para o Setor de Manutenção (Pinturas). O código deverá solicitar ao usuário que seja informado o tamanho em metros quadrados da área a ser pintada. Considere que a cobertura da tinta é de 1 litro para cada 3 metros quadrados e que a tinta é vendida em latas de 18 litros, que custam R\$ 80,00. Informe ao usuário a quantidades de latas de tinta a serem compradas e o preço total. (para simplificação nesse momento, desconsidere a parte decimal dos cálculos. Futuramente trataremos da questão de arredondamentos de números)

# %%
metros_quadrados = float(input("informe o tamanho da área em m²:"))
latas = metros_quadrados // 54
preco_total = latas * 80
print("Quantidade de latas:", latas)
print("Preço total: R$", preco_total)
# Out:
# informe o tamanho da área em m²: 108
# Quantidade de latas: 2.0
# Preço total: R$ 160.0

# %% [markdown]
# ## Estruturas Condicionais
#
# #### 1 - Digamos que você precisa criar um sistema que informe se um aluno está "aprovado", "reprovado" ou "em recuperação". Para tanto você precisa criar um código onde os professores informem o Nome do Aluno, a Disciplina e as quatro notas obtidas no semestre. Após essas informações fornecidas seu sistema precisa avisar ao professor o desempenho final do aluno.

# %% [markdown]
# #### 1.1 - Construa um código que solicite ao professor o Nome do Aluno e a Disciplina cursada. Depois crie o código em que essas informações sejam apresentadas na tela.

# %%
nome = input("informe o nome do aluno: ")
disciplina = input("informe a disciplina cursada: ")
print("nome do aluno:", nome)
print("Disciplina:", disciplina)
# Out:
# informe o nome do aluno: Carla Letícia
# informe a disciplina cursada: Introdução às Ciências de Dados
# nome do aluno: Carla Letícia
# Disciplina: Introdução às Ciências de Dados

# %% [markdown]
# #### 1.2 - Agora construa um código que solicite a esse mesmo professor as quatro notas obtidas pelo aluno no semestre. Em seguida faça com que o sistema mostre na tela cada uma das notas informadas pelo professor, bem como a média final obtida com essas quatro notas.

# %%
from IPython.core.error import InputRejected
nome = input("informe o nome do aluno: ")
disciplina = input("informe a disciplina cursada: ")
nota1 = float(input("informe a primeira nota: "))
nota2 = float(input("informe a segunda nota: "))
nota3 = float(input("informe a terceira nota: "))
nota4 = float(input("informe a quarta nota: "))
media = (nota1 + nota2 + nota3 + nota4) / 4
print("nome do aluno:", nome)
print("Disciplina:", disciplina)
print("Primeira nota:", nota1)
print("Segunda nota:", nota2)
print("Terceira nota:", nota3)
print("Quarta nota:", nota4)
print("Média final:", media)
# Out:
# informe o nome do aluno: Carla Letícia
# informe a disciplina cursada: Introdução às Ciências de Dados
# informe a primeira nota: 7.5
# informe a segunda nota: 9.0
# informe a terceira nota: 8.5
# informe a quarta nota: 10.0
# nome do aluno: Carla Letícia
# Disciplina: Introdução às Ciências de Dados
# Primeira nota: 7.5
# Segunda nota: 9.0
# Terceira nota: 8.5
# Quarta nota: 10.0
# Média final: 8.75

# %% [markdown]
# #### 1.3 - Vamos considerar que para o aluno ser considerado "Aprovado" ele precisa obter a média final na disciplina igual ou superior a 7 (sete). Se a média final for inferior a 7 (sete) ele será considerado "Reprovado". Crie um código que cumpra esse objetivo mostrando na tela o resultado final obtido pelo aluno.

# %%
print("Nome do aluno:", nome)
print("Disciplina:", disciplina)
print("Média final:", media)
if media >= 7:
  print("Resultado: Aprovado")
else:
  print("Resultado: Reprovado")
# Out:
# Nome do aluno: Carla Letícia
# Disciplina: Introdução às Ciências de Dados
# Média final: 8.75
# Resultado: Aprovado

# %% [markdown]
# #### 1.4 - Vamos considerar agora que para o aluno ser considerado "Aprovado" ele precisa obter a média final na disciplina igual ou superior a 7 (sete); se a média final for inferior a 5 (cinco) ele será considerado "Reprovado" e se a média final for maior ou igual a 5 (cinco) e for inferior a 7 (sete) o aluno será considerado "Em Recuperação". Crie um código que cumpra esse objetivo mostrando na tela o resultado final obtido pelo aluno.

# %%
nome = input("informe o nome do aluno: ")
disciplina = input("informe o nome da disciplina: ")
nota1 = float(input("informe a primeira nota: "))
nota2 = float(input("informe a segunda nota: "))
nota3 = float(input("informe a terceira nota: "))
nota4 = float(input("informe a quarta nota: "))
media = (nota1 + nota2 + nota3 +nota4) / 4
print("Nome do aluno:", nome)
print("Disciplina:", disciplina)
print("Média final:", media)
if media >=7:
  print("Resultado: Aprovado")
elif media >= 5:
  print("Resultado: Em recuperação")
else:
  print("Resultado: Reprovado")
# Out:
# informe o nome do aluno: João
# informe o nome da disciplina: Introdução às Ciências de Dados
# informe a primeira nota: 6
# informe a segunda nota: 5
# informe a terceira nota: 7
# informe a quarta nota: 6
# Nome do aluno: João
# Disciplina: Introdução às Ciências de Dados
# Média final: 6.0
# Resultado: Em recuperação

# %% [markdown]
# #### 1.5 - Crie um código que consolide todas as informações anteriores num único texto informativo:
#
# Na disciplina XXX o aluno YYY obeteve as seguintes notas: A, B, C e D.
# Sua média final foi WW. Com isso o aluno YY está Aprovado/Reprovado/Em Recuperação.

# %%
print("Nome do aluno:", nome)
print("Disciplina:", disciplina)
if media >= 7:
  situacao = "Reprovado"
elif media >= 5:
  situacao = "Em Recuperacao"
else:
  situacao = "Reprovado"
print("Na disciplina", disciplina, "o aluno", nome, "obteve as seguintes notas:", nota1, ",", nota2, ",", nota3, "e", nota4, ". Sua média final foi", media, ". Com isso o aluno", nome, "está", situacao + ".")
# Out:
# Nome do aluno: João
# Disciplina: Introdução às Ciências de Dados
# Na disciplina Introdução às Ciências de Dados o aluno João obteve as seguintes notas: 6.0 , 5.0 , 7.0 e 6.0 . Sua média final foi 6.0 . Com isso o aluno João está Em Recuperacao.

# %% [markdown]
# #### 2 -Suponhamos que você trabalha num setor que tem uma meta de atender 200 processos por mês. Crie um código onde seja solicitado do usuário a quantidade de processos atendidos no mês. Depois disso crie um código em que seja apresentado na tela se a meta foi atingida ou não.

# %%
processos = int(input("informe a quantidade de processos atendidos no mês: "))
if processos >= 200:
  print("Meta atingida!")
else:
  print("Meta não atingida.")
# Out:
# informe a quantidade de processos atendidos no mês: 220
# Meta atingida!

# %%
processos = int(input("informe a quantidade de processos atendidos no mês: "))
if processos >= 200:
  print("Meta atingida!")
else:
  print("Meta não atingida.")
# Out:
# informe a quantidade de processos atendidos no mês: 180
# Meta não atingida.

# %% [markdown]
# #### 3 - Suponha que você está atuando na organização de uma competição de futebol com equipes jogando entre si em diversas fases. Nessa competição cada vitória vale 4 pontos, empate vale 2 pontos e em caso de derrota a equipe não pontua.

# %% [markdown]
# 3.1 - Crie um código em que deve haver uma solicitação ao usuário para que informe o nome da equipe, as quantidades de vitórias, empates e derrotas. Ao final devem ser fornecidas ao usuário todas as informações solicitadas bem como a pontuação total da equipe.

# %%
equipe = input("informe o nome da equipe: ")
vitorias = int(input("informe a quantidade de vitorias: "))
empates = int(input("informe a quantidade de empates: "))
derrotas = int(input("informe a quantidade de derrotas: "))
pontuacao = (vitorias * 4) + (empates * 2)
print("Equipe:", equipe)
print("Vitórias:", vitorias)
print("Empates:", empates)
print("Derrotas:", derrotas)
print("Pontuação total:", pontuacao)
# Out:
# informe o nome da equipe: Atletico
# informe a quantidade de vitorias: 6
# informe a quantidade de empates: 3
# informe a quantidade de derrotas: 2
# Equipe: Atletico
# Vitórias: 6
# Empates: 3
# Derrotas: 2
# Pontuação total: 30

# %% [markdown]
# 3.2 - Considerando que se a equipe conseguir atingir 40 pontos ou mais ela será considerada classificada para a próxima fase; Caso a equipe consiga uma pontuação maior ou igual a 30 pontos e menor que 40 pontos, ela estará na "repescagem"; por fim, caso a pontuação da equipe seja inferior a 30 pontos, então, ela estará desclassificada.
#
# Crie um código que seja capaz de informar a situação final da equipe ("classificada", "repescagem" ou "desclassificada") considerando as informações e desempenho informados e apurados na questão 3.1.

# %%
equipe = input("Informe o nome da equipe: ")
vitorias = int(input("Informe a quantidade de vitórias: "))
empates = int(input("Informe a quantidade de empates: "))
derrotas = int(input("Informe a quantidade de derrotas: "))
pontuacao = (vitorias * 4) + (empates * 2)
if pontuacao >= 40:
    situacao = "Classificada"
elif pontuacao >= 30:
    situacao = "Repescagem"
else:
    situacao = "Desclassificada"
print("Equipe:", equipe)
print("Vitórias:", vitorias)
print("Empates:", empates)
print("Derrotas:", derrotas)
print("Pontuação total:", pontuacao)
print("Situação:", situacao)
# Out:
# Informe o nome da equipe:  Atletico
# Informe a quantidade de vitórias: 6
# Informe a quantidade de empates: 3
# Informe a quantidade de derrotas: 2
# Equipe:  Atletico
# Vitórias: 6
# Empates: 3
# Derrotas: 2
# Pontuação total: 30
# Situação: Repescagem

# %% [markdown]
# ### Atividade Complementar
#
#
# Imagine que você é o responsável pelo controle de estoque e pretende criar um sistema que registre os pedidos das pessoas ou informe que não há estoque suficiente para atender a demanda.
#
# Nesse caso digamos que os produtos que estão disponíveis no estoque sejam Sabão (com 75 unidades disponíveis); Detergente (com 30 unidades disponíveis) e Desinfetante (com 50 unidades disponíveis).
#
# Crie um código em que seja pedido ao usuário que informe o produto e a quantidade desejada.
#
# Ao final o sistema precisa analisar o pedido com os valores disponíveis no estoque e informar se o pedido foi feito com sucesso ou não foi possível atender o pedido devido à quantidade em estoque ser inferior à demandada.

# %%
produto = input("Informe o produto (Sabão, Detergente ou Desinfetante): ")
quantidade = int(input("Informe a quantidade desejada: "))
if produto == "Sabão":
    if quantidade <= 75:
        print("Pedido realizado com sucesso!")
    else:
        print("Não foi possível atender o pedido. Estoque insuficiente.")
elif produto == "Detergente":
    if quantidade <= 30:
        print("Pedido realizado com sucesso!")
    else:
        print("Não foi possível atender o pedido. Estoque insuficiente.")
elif produto == "Desinfetante":
    if quantidade <= 50:
        print("Pedido realizado com sucesso!")
    else:
        print("Não foi possível atender o pedido. Estoque insuficiente.")
else:
    print("Produto não encontrado no estoque.")
# Out:
# Informe o produto (Sabão, Detergente ou Desinfetante): Sabão
# Informe a quantidade desejada: 40
# Pedido realizado com sucesso!

# %%
produto = input("Informe o produto (Sabão, Detergente ou Desinfetante): ")
quantidade = int(input("Informe a quantidade desejada: "))
if produto == "Sabão":
    if quantidade <= 75:
        print("Pedido realizado com sucesso!")
    else:
        print("Não foi possível atender o pedido. Estoque insuficiente.")
elif produto == "Detergente":
    if quantidade <= 30:
        print("Pedido realizado com sucesso!")
    else:
        print("Não foi possível atender o pedido. Estoque insuficiente.")
elif produto == "Desinfetante":
    if quantidade <= 50:
        print("Pedido realizado com sucesso!")
    else:
        print("Não foi possível atender o pedido. Estoque insuficiente.")
else:
    print("Produto não encontrado no estoque.")
# Out:
# Informe o produto (Sabão, Detergente ou Desinfetante): Detergente
# Informe a quantidade desejada: 45
# Não foi possível atender o pedido. Estoque insuficiente.

# %%
produto = input("Informe o produto (Sabão, Detergente ou Desinfetante): ")
quantidade = int(input("Informe a quantidade desejada: "))
if produto == "Sabão":
    if quantidade <= 75:
        print("Pedido realizado com sucesso!")
    else:
        print("Não foi possível atender o pedido. Estoque insuficiente.")
elif produto == "Detergente":
    if quantidade <= 30:
        print("Pedido realizado com sucesso!")
    else:
        print("Não foi possível atender o pedido. Estoque insuficiente.")
elif produto == "Desinfetante":
    if quantidade <= 50:
        print("Pedido realizado com sucesso!")
    else:
        print("Não foi possível atender o pedido. Estoque insuficiente.")
else:
    print("Produto não encontrado no estoque.")
# Out:
# Informe o produto (Sabão, Detergente ou Desinfetante): Amaciante
# Informe a quantidade desejada: 10
# Produto não encontrado no estoque.

# %% [markdown]
# ## Operando com Strings

# %% [markdown]
# #### 1 - Considere a variável nome = "Filipe Mendonça de Lima". Faça linhas de código em que mostre na tela as seguintes informações:
# 1.1 - Seu nome possui XX caracteres
#
# 1.2 - Seu primeiro nome é: Filipe
#
# 1.3 - Seu nome do meio é: Mendonça
#
# 1.4 - Seu último nome é: Lima

# %%
nome = "Filipe Mendonça de Lima"
print("1.1 - Seu nome possui", len(nome), "caracteres")
partes = nome.split()
print("1.2 - Seu primeiro nome é:", partes[0])
print("1.3 - Seu nome do meio é:", partes[1])
print("1.4 - Seu último nome é:", partes[3])
# Out:
# 1.1 - Seu nome possui 23 caracteres
# 1.2 - Seu primeiro nome é: Filipe
# 1.3 - Seu nome do meio é: Mendonça
# 1.4 - Seu último nome é: Lima

# %% [markdown]
# #### 2 - Considere a variável email = filipe.mlima@ufrpe.br. Crie linhas de código em que mostre na tela as seguintes informações:
# 2.1 - O E-mail possui 21 caracteres
#
# 2.2 - O usuário do e-mail filipe.mlima@ufrpe.br é: filipe.mlima
#
# 2.3 - O domínio do e-mail filipe.mlima@ufrpe.br é: ufrpe.br

# %%
email = "filipe.mlima@ufrpe.br"
print("2.1 - O e-mail possui", len(email), "caracteres")
partes = email.split("@")
print("2.2 - O usuário do e-mail", email, "é:", partes[0])
print("2.3 - O domínio do e-mail", email, "é:", partes[1])
# Out:
# 2.1 - O e-mail possui 21 caracteres
# 2.2 - O usuário do e-mail filipe.mlima@ufrpe.br é: filipe.mlima
# 2.3 - O domínio do e-mail filipe.mlima@ufrpe.br é: ufrpe.br

# %% [markdown]
# #### 3 - Converta os números abaixo para o padrão brasileiro de milhar/decimal (arredonde todos os números para 2 casas decimais):
#
# 3.1 - 4550.8756
#
# 3.2 - 12859.45869
#
# 3.3 - 1255465879.25687

# %%
# Números
n1 = 4550.8756
n2 = 12859.45869
n3 = 1255465879.25687
# Formatação para o padrão brasileiro
print(f"{n1:,.2f}".replace(",", "X").replace(".", ",").replace("X", "."))
print(f"{n2:,.2f}".replace(",", "X").replace(".", ",").replace("X", "."))
print(f"{n3:,.2f}".replace(",", "X").replace(".", ",").replace("X", "."))
# Out:
# 4.550,88
# 12.859,46
# 1.255.465.879,26

# %% [markdown]
# #### 4 - Dadas as variáveis nota1 = 8.5 e nota2 = 7.5, crie linhas de código onde sejam apresentadas na tela as seguintes informações:
# 4.1 - A nota da Avaliação 1 foi 8.5 e a nota da Avaliação 2 foi 7.5;
#
# 4.2 - A média das duas avaliações foi 8.0;
#
# 4.3 - A nota da Avaliação 1 foi 8,5 e a nota da Avaliação 2 foi 7,5;
#
# 4.4 - A média das duas avaliações foi 8,0;
# Obs: Utilize os nomes das variáveis para efetuar os cálculos e conversões.

# %%
# Variáveis
nota1 = 8.5
nota2 = 7.5
# Média
media = (nota1 + nota2) / 2
# 4.1
print(f"A nota da Avaliação 1 foi {nota1} e a nota da Avaliação 2 foi {nota2}.")
# 4.2
print(f"A média das duas avaliações foi {media}.")
# 4.3
print(f"A nota da Avaliação 1 foi {str(nota1).replace('.', ',')} e a nota da Avaliação 2 foi {str(nota2).replace('.', ',')}.")
# 4.4
print(f"A média das duas avaliações foi {str(media).replace('.', ',')}.")
# Out:
# A nota da Avaliação 1 foi 8.5 e a nota da Avaliação 2 foi 7.5.
# A média das duas avaliações foi 8.0.
# A nota da Avaliação 1 foi 8,5 e a nota da Avaliação 2 foi 7,5.
# A média das duas avaliações foi 8,0.

# %% [markdown]
# #### 5- Dadas as variáveis energia = 1200.80 e saude = 2200.60 , crie linhas de código onde sejam apresentadas na tela as seguintes informações:
# 5.1 - O valor da despesa com Energia Elétrica foi R$\$$ 1,200.80 e a despesa com Saúde foi R$\$$ 2,200.60
#
# 5.2 - O valor total das despesas foi de R$\$$ 3,401.40 e a média de gastos foi de R$\$$ 1,700.70
#
# 5.3 - O valor da despesa com Energia Elétrica foi R$\$$ 1.200,80 e a despesa com Saúde foi R$\$$ 2.200,60
#
# 5.4 - O valor total das despesas foi de R$\$$ 3.401,40 e a média de gastos foi de R$\$$ 1.700,70

# %%
# Variáveis
energia = 1200.80
saude = 2200.60
# Cálculos
total = energia + saude
media = total / 2
# 5.1
print(f"O valor da despesa com Energia Elétrica foi R$ {energia:,.2f} e a despesa com Saúde foi R$ {saude:,.2f}")
# 5.2
print(f"O valor total das despesas foi de R$ {total:,.2f} e a média de gastos foi de R$ {media:,.2f}")
# 5.3
print(f"O valor da despesa com Energia Elétrica foi R$ {energia:,.2f}".replace(",", "X").replace(".", ",").replace("X", ".") +
      f" e a despesa com Saúde foi R$ {saude:,.2f}".replace(",", "X").replace(".", ",").replace("X", "."))
# 5.4
print(f"O valor total das despesas foi de R$ {total:,.2f}".replace(",", "X").replace(".", ",").replace("X", ".") +
      f" e a média de gastos foi de R$ {media:,.2f}".replace(",", "X").replace(".", ",").replace("X", "."))
# Out:
# O valor da despesa com Energia Elétrica foi R$ 1,200.80 e a despesa com Saúde foi R$ 2,200.60
# O valor total das despesas foi de R$ 3,401.40 e a média de gastos foi de R$ 1,700.70
# O valor da despesa com Energia Elétrica foi R$ 1.200,80 e a despesa com Saúde foi R$ 2.200,60
# O valor total das despesas foi de R$ 3.401,40 e a média de gastos foi de R$ 1.700,70

# %% [markdown]
# #### 6 - Crie linhas de código em que o usuário deve informar apenas os números do CPF (que contém 11 caracteres). Nessas linhas de código você precisa criar um alerta de erro caso o usuário preencha os caracteres "." ou "-". Depois disso crie um código que mostre na tela o CPF no formato tradicional (xxx.xxx.xxx-xx). Resumindo: O usuário precisa informar apenas os números do CPF(xxxxxxxxxxx), mas, no momento da exibição na tela o CPF informado deve estar no formato xxx.xxx.xxx-xx.

# %%
cpf = input("Digite apenas os 11 números do CPF: ")
# Validação
if "." in cpf or "-" in cpf:
    print("Erro! Digite apenas os números do CPF, sem pontos ou hífen.")
elif len(cpf) != 11 or not cpf.isdigit():
    print("Erro! O CPF deve conter exatamente 11 números.")
els
    cpf_formatado = f"{cpf[:3]}.{cpf[3:6]}.{cpf[6:9]}-{cpf[9:]}"
    print("CPF:", cpf_formatado)
# Out:
# Digite apenas os 11 números do CPF: 11538861320
# CPF: 115.388.613-20

# %% [markdown]
# 7 - Crie linhas de código em que o usuário deve informar apenas os números do CPF (que contém 11 caracteres). Neste caso o usuário poderá informar o CPF no formato que quiser, contanto que ao final haja uma codificação de CPF válida (11 caracteres numéricos).
#
# Resumindo: O usuário pode informar o CPF no formato que desejar, mas, no momento da exibição na tela o CPF informado deve estar no formato xxx.xxx.xxx-xx. Caso o que o usuário informar não resulte no formato padrão dos CPF (xxx.xxx.xxx-xx) uma mensagem de erro deverá ser informada na tela.

# %%
cpf = input("Digite o CPF: ")
cpf = ''.join(caractere for caractere in cpf if caractere.isdigit())
if len(cpf) != 11:
    print("Erro! O CPF informado é inválido.")
else:
    cpf_formatado = f"{cpf[:3]}.{cpf[3:6]}.{cpf[6:9]}-{cpf[9:]}"
    print("CPF:", cpf_formatado)
# Out:
# Digite o CPF: 765.0986.567-09
# Erro! O CPF informado é inválido.

# %%
cpf = input("Digite o CPF: ")
cpf = ''.join(caractere for caractere in cpf if caractere.isdigit())
if len(cpf) != 11:
    print("Erro! O CPF informado é inválido.")
else:
    cpf_formatado = f"{cpf[:3]}.{cpf[3:6]}.{cpf[6:9]}-{cpf[9:]}"
    print("CPF:", cpf_formatado)
# Out:
# Digite o CPF: 54326753265
# CPF: 543.267.532-65

# %%
cpf = input("Digite o CPF: ")
cpf = ''.join(caractere for caractere in cpf if caractere.isdigit())
if len(cpf) != 11:
    print("Erro! O CPF informado é inválido.")
else:
    cpf_formatado = f"{cpf[:3]}.{cpf[3:6]}.{cpf[6:9]}-{cpf[9:]}"
    print("CPF:", cpf_formatado)
# Out:
# Digite o CPF: 564.097.643 78
# CPF: 564.097.643-78

# %% [markdown]
# ### Exercícios Complementares

# %% [markdown]
# 1 - Crie linhas de código onde o usuário tenha que informar o número do celular. Considerando como padrão que os números de celular sempre devem começar com "9" e que no total os números de celular possuem 10 caracteres, sendo comporto por 9 números e um "-" (9xxxx-xxxx).
#
# Nessas linhas de código o usuário poderá optar em informar ou não o primeiro dígito obrigatório ("9"), mas, ao final, seu programa deve sempre informar na tela o número do celular no formato padrão 9xxxx-xxxx.
#
# Mas, é imporante salientar que seu sistema deve informar possíveis erros de preenchimento caso as informações do usuário não resultem no formato padrão citado acima.

# %%
celular = input("Digite o número do celular: ")
celular = ''.join(c for c in celular if c.isdigit())
if len(celular) == 8:
    celular = "9" + celular
if len(celular) != 9:
    print("Erro! O número do celular deve possuir 9 dígitos.")
elif celular[0] != "9":
    print("Erro! O número do celular deve começar com o dígito 9.")
else:
    celular_formatado = f"{celular[:5]}-{celular[5:]}"
    print("Celular:", celular_formatado)
# Out:
# Digite o número do celular: 8791477448
# Erro! O número do celular deve possuir 9 dígitos.

# %%
celular = input("Digite o número do celular: ")
celular = ''.join(c for c in celular if c.isdigit())
if len(celular) == 8:
    celular = "9" + celular
if len(celular) != 9:
    print("Erro! O número do celular deve possuir 9 dígitos.")
elif celular[0] != "9":
    print("Erro! O número do celular deve começar com o dígito 9.")
else:
    celular_formatado = f"{celular[:5]}-{celular[5:]}"
    print("Celular:", celular_formatado)
# Out:
# Digite o número do celular: 987542457
# Celular: 98754-2457

# %%
celular = input("Digite o número do celular: ")
celular = ''.join(c for c in celular if c.isdigit())
if len(celular) == 8:
    celular = "9" + celular
if len(celular) != 9:
    print("Erro! O número do celular deve possuir 9 dígitos.")
elif celular[0] != "9":
    print("Erro! O número do celular deve começar com o dígito 9.")
else:
    celular_formatado = f"{celular[:5]}-{celular[5:]}"
    print("Celular:", celular_formatado)
# Out:
# Digite o número do celular: 897654213
# Erro! O número do celular deve começar com o dígito 9.

# %% [markdown]
# 2 - Crie linhas de código que permitam que o usuário informe o valor do seu salário e de suas despesas no padrão monetário brasileiro (por exemplo Salário = 5.520,45 e Despesas = 3.895,86). A partir dessas informações seu sistema deve apurar o "Resultado Financeiro" (que é o resultado da diferença entre o valor do "Salário" e o valor das "Despesas") e também apurar a "Situação Financeira" (que será considerada "Boa", quando o Resultado Financeiro for maior ou igual a zero, e "Ruim", quando o Resultado Financeiro for negativo).
#
# Ao final o seu sistema deve mostrar na tela as seguintes informações:
#
# Salário: R$\$$ 5.520,45
#
# Despesas: R$ 3.895,86
#
# Resultado Financeiro: R$\$$ 1.624,59
#
# Situação Financeira: Boa

# %%
salario = input("Digite o salário (ex.: 5.520,45): ")
despesas = input("Digite as despesas (ex.: 3.895,86): ")
salario = float(salario.replace(".", "").replace(",", "."))
despesas = float(despesas.replace(".", "").replace(",", "."))
resultado = salario - despesas
if resultado >= 0:
    situacao = "Boa"
else:
    situacao = "Ruim"
def moeda_br(valor):
    return f"{valor:,.2f}".replace(",", "X").replace(".", ",").replace("X", ".")
print(f"Salário: R$ {moeda_br(salario)}")
print(f"Despesas: R$ {moeda_br(despesas)}")
print(f"Resultado Financeiro: R$ {moeda_br(resultado)}")
print(f"Situação Financeira: {situacao}")
# Out:
# Digite o salário (ex.: 5.520,45): 5.520,45
# Digite as despesas (ex.: 3.895,86): 3.895,86
# Salário: R$ 5.520,45
# Despesas: R$ 3.895,86
# Resultado Financeiro: R$ 1.624,59
# Situação Financeira: Boa

# %% [markdown]
# 3 - Aproveitando a questão anterior (Questão 2), crie linhas de código que faça extamente o que se pede na Questão 2, porém, desta vez o seu sistema deve possuir um código de controle de validação que emita uma mensagem de erro quando o usuário não preencher (deixar em branco) o Salário ou as Despesas ou caso o usuário preencha valores que não correspondam ao padrão monetário brasileiro (por exemplo colocar letras ou caracteres especiais no lugar dos valores numéricos).
#
# Assim, apenas uma das duas situação abaixo deve aparecer na tela para ao usuário:
#
# QUANDO O USUÁRIO NÃO CUMPRIR AS REGRAS DE VALIDAÇÃO:
# Erro no preenchimento! Favor informar valores numéricos válidos!
#
# QUANDO O USUÁRIO CUMPRIR AS REGRAS DE VALIDAÇÃO:
# Salário: R$\$$ 5.520,45
# Despesas: R$\$$ 3.895,86
# Resultado Financeiro: R$\$$ 1.624,59
# Situação Financeira: Boa

# %%
salario = input("Digite o salário (ex.: 5.520,45): ")
despesas = input("Digite as despesas (ex.: 3.895,86): ")
try:
    if salario.strip() == "" or despesas.strip() == "":
        raise ValueError
    salario = float(salario.replace(".", "").replace(",", "."))
    despesas = float(despesas.replace(".", "").replace(",", "."))
    resultado = salario - despesas
    if resultado >= 0:
        situacao = "Boa"
    else:
        situacao = "Ruim"
    def moeda_br(valor):
        return f"{valor:,.2f}".replace(",", "X").replace(".", ",").replace("X", ".")
    print(f"Salário: R$ {moeda_br(salario)}")
    print(f"Despesas: R$ {moeda_br(despesas)}")
    print(f"Resultado Financeiro: R$ {moeda_br(resultado)}")
    print(f"Situação Financeira: {situacao}")
except:
    print("Erro no preenchimento! Favor informar valores numéricos válidos!")
# Out:
# Digite o salário (ex.: 5.520,45): 5.520,45
# Digite as despesas (ex.: 3.895,86): 3.895,86
# Salário: R$ 5.520,45
# Despesas: R$ 3.895,86
# Resultado Financeiro: R$ 1.624,59
# Situação Financeira: Boa

# %%
salario = input("Digite o salário (ex.: 5.520,45): ")
despesas = input("Digite as despesas (ex.: 3.895,86): ")
try:
    if salario.strip() == "" or despesas.strip() == "":
        raise ValueError
    salario = float(salario.replace(".", "").replace(",", "."))
    despesas = float(despesas.replace(".", "").replace(",", "."))
    resultado = salario - despesas
    if resultado >= 0:
        situacao = "Boa"
    else:
        situacao = "Ruim"
    def moeda_br(valor):
        return f"{valor:,.2f}".replace(",", "X").replace(".", ",").replace("X", ".")
    print(f"Salário: R$ {moeda_br(salario)}")
    print(f"Despesas: R$ {moeda_br(despesas)}")
    print(f"Resultado Financeiro: R$ {moeda_br(resultado)}")
    print(f"Situação Financeira: {situacao}")
except:
    print("Erro no preenchimento! Favor informar valores numéricos válidos!")
# Out:
# Digite o salário (ex.: 5.520,45): abc
# Digite as despesas (ex.: 3.895,86): 3000
# Erro no preenchimento! Favor informar valores numéricos válidos!

# %%
salario = input("Digite o salário (ex.: 5.520,45): ")
despesas = input("Digite as despesas (ex.: 3.895,86): ")
try:
    if salario.strip() == "" or despesas.strip() == "":
        raise ValueError
    salario = float(salario.replace(".", "").replace(",", "."))
    despesas = float(despesas.replace(".", "").replace(",", "."))
    resultado = salario - despesas
    if resultado >= 0:
        situacao = "Boa"
    else:
        situacao = "Ruim"
    def moeda_br(valor):
        return f"{valor:,.2f}".replace(",", "X").replace(".", ",").replace("X", ".")
    print(f"Salário: R$ {moeda_br(salario)}")
    print(f"Despesas: R$ {moeda_br(despesas)}")
    print(f"Resultado Financeiro: R$ {moeda_br(resultado)}")
    print(f"Situação Financeira: {situacao}")
except:
    print("Erro no preenchimento! Favor informar valores numéricos válidos!")
# Out:
# Digite o salário (ex.: 5.520,45):
# Digite as despesas (ex.: 3.895,86): 3000
# Erro no preenchimento! Favor informar valores numéricos válidos!

# %% [markdown]
# ## Operando com Listas

# %% [markdown]
# #### Dada a lista produtos = ["caneta", "mouse", "lapis", "borracha", "grampeador", "cartucho"], responda as questões 1 a 4:

# %% [markdown]
# 1 - Crie um código que permita identificar quantos produtos diferentes há no estoque. (Não é para somar a quantidade de unidades dos produtos no estoque e sim informar quantos itens compõem a lista "produtos").

# %%
produtos = ["caneta", "mouse", "lapis", "borracha", "grampeador", "cartucho"]
print("Há", len(produtos), "produtos diferentes no estoque.")
# Out:
# Há 6 produtos diferentes no estoque.

# %% [markdown]
# 2 - Crie um código que informe a posição (índice) da "borracha" na lista "produtos".

# %%
produtos = ["caneta", "mouse", "lapis", "borracha", "grampeador", "cartucho"]
print("O índice da borracha é:", produtos.index("borracha"))
# Out:
# O índice da borracha é: 3

# %% [markdown]
# 3 - Faça um código que crie uma nova lista composta apenas pelos produtos "lapis", "borracha", "grampeador".

# %%
produtos = ["caneta", "mouse", "lapis", "borracha", "grampeador", "cartucho"]
produtos[1] = "caderno"
produtos[5] = "apagador"
print(produtos)
# Out:
# ['caneta', 'caderno', 'lapis', 'borracha', 'grampeador', 'apagador']

# %% [markdown]
# 4 - Crie um código que substitua o produto "mouse" por "caderno" e o produto "cartucho" por "apagador".

# %%
produtos = ["caneta", "mouse", "lapis", "borracha", "grampeador", "cartucho"]
produtos[1] = "caderno"
produtos[5] = "apagador"
print(produtos)
# Out:
# ['caneta', 'caderno', 'lapis', 'borracha', 'grampeador', 'apagador']

# %% [markdown]
# ### Digamos que o setor onde você trabalha quer instituir um controle de almoxarifado e possui as seguintes informações: produtos = ["canettta", "mouseeeeee", "lapis", "borracha", "grampeador", "cartuxxo"] quantidades = [250, 50, 320, 450, 70, 190] Com base nessas informações responda as questões 5 a 10:

# %% [markdown]
# 5 - Crie um código que faça a correção dos erros de digitação ocorridos na lista "produtos".

# %%
produtos = ["canettta", "mouseeeeee", "lapis", "borracha", "grampeador", "cartuxxo"]
quantidades = [250, 50, 320, 450, 70, 190]
produtos = ["caneta", "mouse", "lapis", "borracha", "grampeador", "cartucho"]
print("Lista corrigida:", produtos)
# Out:
# Lista corrigida: ['caneta', 'mouse', 'lapis', 'borracha', 'grampeador', 'cartucho']

# %% [markdown]
# 6 - Crie um sistema onde seja possível um usuário consultar quantas unidades de um produto constam no almoxarifado. Nesse sistema o usuário informa o nome do produto e o sistema deve informar o seguinte:
#
# Há XX unidades do produto YY no almoxarifado.
#
# importante: considere que o usuário sempre informará um produto que consta no estoque.

# %%
produto_procurado = input("Digite o nome do produto para consulta: ").lower().strip()
indice = produtos.index(produto_procurado)
quantidade = quantidades[indice]
print(f"Há {quantidade} unidades do produto {produto_procurado} no almoxarifado.")
# Out:
# Digite o nome do produto para consulta: grampeador
# Há 70 unidades do produto grampeador no almoxarifado.

# %% [markdown]
# 7 - Semelhante à questão 6, crie um sistema onde seja possível um usuário informar o produto que ele deseja consultar no almoxarifado. Nesse sistema o usuário informa o nome do produto e o sistema deve se comportar das seguintes formas:
#
# Quando o produto informado existir no almoxarifado, informar: "Há XX unidades do produto YY no almoxarifado."
#
# Quando o produto informado não existir no almoxarifado ou o usuário informar um produto com erro de digitação: "O produto ZZ não consta no almoxarifado."

# %%
produto_procurado = input("Digite o nome do produto para consulta: ").lower().strip()
if produto_procurado in produtos:
    indice = produtos.index(produto_procurado)
    quantidade = quantidades[indice]
    print(f"Há {quantidade} unidades do produto {produto_procurado} no almoxarifado.")
else:
    print(f"O produto {produto_procurado} não consta no almoxarifado.")
# Out:
# Digite o nome do produto para consulta: Corretivo
# O produto corretivo não consta no almoxarifado.

# %%
produto_procurado = input("Digite o nome do produto para consulta: ").lower().strip()
if produto_procurado in produtos:
    indice = produtos.index(produto_procurado)
    quantidade = quantidades[indice]
    print(f"Há {quantidade} unidades do produto {produto_procurado} no almoxarifado.")
else:
    print(f"O produto {produto_procurado} não consta no almoxarifado.")
# Out:
# Digite o nome do produto para consulta: grampeador
# Há 70 unidades do produto grampeador no almoxarifado.

# %% [markdown]
# 8 - Crie linhas de código que permitam identificar qual o produto que possui mais unidades e qual possui menos unidades no almoxarifado.

# %%
maior_quantidade = max(quantidades)
indice_maior = quantidades.index(maior_quantidade)
produto_maior = produtos[indice_maior]
menor_quantidade = min(quantidades)
indice_menor = quantidades.index(menor_quantidade)
produto_menor = produtos[indice_menor]
print(f"Mais unidades: {produto_maior} ({maior_quantidade} unidades)")
print(f"Menos unidades: {produto_menor} ({menor_quantidade} unidades)")
# Out:
# Mais unidades: borracha (450 unidades)
# Menos unidades: mouse (50 unidades)

# %% [markdown]
# 9 - Crie um código que permita saber a quantidade total de produtos que há no almoxarifado, ou seja, o sistema deve somar todos os itens da lista "quantidades".

# %%
total_itens = sum(quantidades)
print(f"A quantidade total de produtos no almoxarifado é: {total_itens}")
# Out:
# A quantidade total de produtos no almoxarifado é: 1330

# %% [markdown]
# 10 - Digamos que o setor não utilizará mais o produto "cartucho" e irá trocar com outro setor todos esses "cartuchos" por 30 unidades de "teclado" para computadores. Assim, crie linhas de código que atualize as listas "produtos" e "quantidades" para que o controle de almoxarifado proceda com essas mudanças.

# %%
indice_troca = produtos.index("cartucho")
produtos[indice_troca] = "teclado"
quantidades[indice_troca] = 30
print("Produtos atualizados:", produtos)
print("Quantidades atualizadas:", quantidades)
# Out:
# Produtos atualizados: ['caneta', 'mouse', 'lapis', 'borracha', 'grampeador', 'teclado']
# Quantidades atualizadas: [250, 50, 320, 450, 70, 30]

# %% [markdown]
# ### EXERCÍCIO COMPLEMENTAR

# %% [markdown]
# Digamos que você trabalha num setor que atende o público por meio de processos administrativos. As listas representam os meses e as quantidades de processos atendidos, respectivamente:
#
# meses = ["janeiro", "fevereiro", "março", "abril", "maio", "junho", "julho", "agosto", "setembro", "outubro", "novembro", "dezembro"]
#
# atendimentos_semestre_1 = [350, 280, 420, 560, 325, 295]
# atendimentos_semestre_2 = [490, 550, 620, 516, 380, 478]
#
# Crie um sistema onde seja possível evidenciar na tela o meses em que ocorreram as maiores e menores quantidades de atendimentos, bem como evidenciar o percentual que esses atendimentos representam em relação ao total de atendimentos no ano.
#
# No sistema deve ser evidenciada as seguintes menagens:
#
#
# "O mês de xxx foi o que registrou a maior quantidade de atendimentos no ano com yyy atendimentos, o que representa zz % do total de atendimentos no ano."
#
# "O mês de xxx foi o que registrou a menor quantidade de atendimentos no ano com yyy atendimentos, o que representa apenas zz % do total de atendimentos no ano."

# %%
meses = ["janeiro", "fevereiro", "março", "abril", "maio", "junho",
         "julho", "agosto", "setembro", "outubro", "novembro", "dezembro"]
atendimentos_semestre_1 = [350, 280, 420, 560, 325, 295]
atendimentos_semestre_2 = [490, 550, 620, 516, 380, 478]
atendimentos_ano = atendimentos_semestre_1 + atendimentos_semestre_2
total_atendimentos = sum(atendimentos_ano)
maior_quantidade = max(atendimentos_ano)
indice_maior = atendimentos_ano.index(maior_quantidade)
mes_maior = meses[indice_maior]
p_maior = round((maior_quantidade / total_atendimentos) * 100, 2)
menor_quantidade = min(atendimentos_ano)
indice_menor = atendimentos_ano.index(menor_quantidade)
mes_menor = meses[indice_menor]
p_menor = round((menor_quantidade / total_atendimentos) * 100, 2)
print(f"O mês de {mes_maior} foi o que registrou a maior quantidade de atendimentos no ano com {maior_quantidade} atendimentos, o que representa {p_maior} % do total de atendimentos no ano.")
print(f"O mês de {mes_menor} foi o que registrou a menor quantidade de atendimentos no ano com {menor_quantidade} atendimentos, o que representa apenas {p_menor} % do total de atendimentos no ano.")
# Out:
# O mês de setembro foi o que registrou a maior quantidade de atendimentos no ano com 620 atendimentos, o que representa 11.78 % do total de atendimentos no ano.
# O mês de fevereiro foi o que registrou a menor quantidade de atendimentos no ano com 280 atendimentos, o que representa apenas 5.32 % do total de atendimentos no ano.
